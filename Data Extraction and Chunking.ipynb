# %%
# from unstructured.partition.pdf import partition_pdf
from unstructured.partition.auto import partition

# %%
output_path = "images"
file_path = "Attention.pdf"
# The Foundation of Foundation Models.pdf

# Reference: https://docs.unstructured.io/open-source/core-functionality/chunking
chunks = partition(
    filename=file_path,
    pdf_infer_table_structure=True,  # extract tables
    strategy="hi_res",  # mandatory to infer tables
    extract_image_block_types=[
        "Image"
    ],  # Add 'Table' to list to extract image of tables
    # image_output_dir_path=output_path,  # if None, images and tables will saved in base64
    extract_image_block_to_payload=True,  # if true, will extract base64 for API usage
    chunking_strategy="by_title",  # or 'basic', by_page - api
    max_characters=10000,  # defaults to 500
    combine_text_under_n_chars=2000,  # defaults to 0
    new_after_n_chars=6000,
    # extract_images_in_pdf=True,          # deprecated
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\unstructured\partition\pdf.py:192, in _partition_pdf_or_image_local(filename, file, is_image, infer_table_structure, include_page_breaks, ocr_languages, model_name, **kwargs)
#     191 try:
# --> 192     from unstructured_inference.inference.layout import (
#     193         process_data_with_model,
#     194         process_file_with_model,
#     195     )
#     196 except ModuleNotFoundError as e:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\unstructured_inference\inference\layout.py:19
#      13 from unstructured_inference.inference.elements import (
#      14     EmbeddedTextRegion,
#      15     ImageTextRegion,
#      16     Rectangle,
#      17     TextRegion,
#      18 )
# ---> 19 from unstructured_inference.inference.layoutelement import (
#      20     LayoutElement,
#      21     LocationlessLayoutElement,
#      22     merge_inferred_layout_with_extracted_layout,
#      23 )
#      24 from unstructured_inference.inference.ordering import order_layout
#
# ImportError: cannot import name 'LocationlessLayoutElement' from 'unstructured_inference.inference.layoutelement' (C:\Users\sanket\AppData\Local\Programs\Python\Python310\lib\site-packages\unstructured_inference\inference\layoutelement.py)
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 6
#       2 file_path = "Attention.pdf"
#       3 # The Foundation of Foundation Models.pdf
#       4
#       5 # Reference: https://docs.unstructured.io/open-source/core-functionality/chunking
# ----> 6 chunks = partition(
#       7     filename=file_path,
#       8     pdf_infer_table_structure=True,  # extract tables
#       9     strategy="hi_res",  # mandatory to infer tables
#      10     extract_image_block_types=[
#      11         "Image"
#      12     ],  # Add 'Table' to list to extract image of tables
#      13     # image_output_dir_path=output_path,  # if None, images and tables will saved in base64
#      14     extract_image_block_to_payload=True,  # if true, will extract base64 for API usage
#      15     chunking_strategy="by_title",  # or 'basic', by_page - api
#      16     max_characters=10000,  # defaults to 500
#      17     combine_text_under_n_chars=2000,  # defaults to 0
#      18     new_after_n_chars=6000,
#      19     # extract_images_in_pdf=True,          # deprecated
#      20 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\unstructured\partition\auto.py:180, in partition(filename, content_type, file, file_filename, url, include_page_breaks, strategy, encoding, paragraph_grouper, headers, ssl_verify, ocr_languages, pdf_infer_table_structure, xml_keep_tags, data_source_metadata, **kwargs)
#     173     elements = partition_md(
#     174         filename=filename,
#     175         file=file,
#     176         include_page_breaks=include_page_breaks,
#     177         **kwargs,
#     178     )
#     179 elif filetype == FileType.PDF:
# --> 180     elements = partition_pdf(
#     181         filename=filename,  # type: ignore
#     182         file=file,  # type: ignore
#     183         url=None,
#     184         include_page_breaks=include_page_breaks,
#     185         infer_table_structure=pdf_infer_table_structure,
#     186         strategy=strategy,
#     187         ocr_languages=ocr_languages,
#     188         **kwargs,
#     189     )
#     190 elif (filetype == FileType.PNG) or (filetype == FileType.JPG):
#     191     elements = partition_image(
#     192         filename=filename,  # type: ignore
#     193         file=file,  # type: ignore
#    (...)
#     198         **kwargs,
#     199     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\unstructured\documents\elements.py:214, in process_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 @wraps(func)
#     213 def wrapper(*args, **kwargs):
# --> 214     elements = func(*args, **kwargs)
#     215     sig = inspect.signature(func)
#     216     params = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\unstructured\file_utils\filetype.py:531, in add_metadata_with_filetype.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     529 @wraps(func)
#     530 def wrapper(*args, **kwargs):
# --> 531     elements = func(*args, **kwargs)
#     532     sig = inspect.signature(func)
#     533     params = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\unstructured\partition\pdf.py:85, in partition_pdf(filename, file, include_page_breaks, strategy, infer_table_structure, ocr_languages, max_partition, include_metadata, metadata_filename, **kwargs)
#      55 """Parses a pdf document into a list of interpreted elements.
#      56 Parameters
#      57 ----------
#    (...)
#      82     no maximum is applied. Only applies to the "ocr_only" strategy.
#      83 """
#      84 exactly_one(filename=filename, file=file)
# ---> 85 return partition_pdf_or_image(
#      86     filename=filename,
#      87     file=file,
#      88     include_page_breaks=include_page_breaks,
#      89     strategy=strategy,
#      90     infer_table_structure=infer_table_structure,
#      91     ocr_languages=ocr_languages,
#      92     max_partition=max_partition,
#      93     **kwargs,
#      94 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\unstructured\partition\pdf.py:151, in partition_pdf_or_image(filename, file, is_image, include_page_breaks, strategy, infer_table_structure, ocr_languages, max_partition, **kwargs)
#     149     with warnings.catch_warnings():
#     150         warnings.simplefilter("ignore")
# --> 151         layout_elements = _partition_pdf_or_image_local(
#     152             filename=filename,
#     153             file=spooled_to_bytes_io_if_needed(file),
#     154             is_image=is_image,
#     155             infer_table_structure=infer_table_structure,
#     156             include_page_breaks=include_page_breaks,
#     157             ocr_languages=ocr_languages,
#     158             **kwargs,
#     159         )
#     161 elif strategy == "fast":
#     162     return extracted_elements
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\unstructured\utils.py:43, in requires_dependencies.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      34 if len(missing_deps) > 0:
#      35     raise ImportError(
#      36         f"Following dependencies are missing: {', '.join(missing_deps)}. "
#      37         + (
#    (...)
#      41         ),
#      42     )
# ---> 43 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\unstructured\partition\pdf.py:204, in _partition_pdf_or_image_local(filename, file, is_image, infer_table_structure, include_page_breaks, ocr_languages, model_name, **kwargs)
#     197     raise Exception(
#     198         "unstructured_inference module not found... try running pip install "
#     199         "unstructured[local-inference] if you installed the unstructured library as a package. "
#     200         "If you cloned the unstructured repository, try running make install-local-inference "
#     201         "from the root directory of the repository.",
#     202     ) from e
#     203 except ImportError as e:
# --> 204     raise Exception(
#     205         "There was a problem importing unstructured_inference module - it may not be installed "
#     206         "correctly... try running pip install unstructured[local-inference] if you installed "
#     207         "the unstructured library as a package. If you cloned the unstructured repository, try "
#     208         "running make install-local-inference from the root directory of the repository.",
#     209     ) from e
#     211 model_name = model_name if model_name else os.environ.get("UNSTRUCTURED_HI_RES_MODEL_NAME")
#     212 if file is None:
#
# Exception: There was a problem importing unstructured_inference module - it may not be installed correctly... try running pip install unstructured[local-inference] if you installed the unstructured library as a package. If you cloned the unstructured repository, try running make install-local-inference from the root directory of the repository.
